# %% [markdown]
# # Multilevel modeling

# %%
# libraries
library(rstan)
rstan_options(auto_write = TRUE)
options(mc.cores = parallel::detectCores())
library(brms)
library(loo)
library(haven)
library(sdazar)
library(data.table)
library(MASS)

library(bayesplot)
library(forcats)
library(ggplot2)
library(patchwork)
options(repr.plot.width = 5, repr.plot.height = 3)
source('Rutils/functions.R')

# %%
# load data

df = data.table(read_stata('../data/LA_uncertainty.dta'))

# %%
df = df[, .(ctry, year, gdp_pc, median)]
setnames(df, c('gdp_pc', 'median'), c('gdp', 'le'))
df = df[complete.cases(df)]

df[, le_log := scale(log(le), scale=FALSE)]
df[, gdp_log := scale(log(gdp), scale=FALSE)]
df[, year_log := scale(log(year), scale=FALSE)]

# %%
df[, year_c := scale(year, scale=FALSE)]

# %%
head(df)
# Out:
#   ctry year gdp      le       le_log     gdp_log       year_log
# 1 2020 1900 2875.352 41.14719 -0.2832005 -0.0001331202 -0.03272400
# 2 2020 1905 3478.617 36.49913 -0.4030676  0.1903267151 -0.03009587
# 3 2020 1910 3821.710 41.14719 -0.2832005  0.2843900144 -0.02747464
# 4 2020 1915 3243.723 38.29062 -0.3551511  0.1204137191 -0.02486026
# 5 2020 1920 3473.069 39.97605 -0.3120756  0.1887304573 -0.02225270
# 6 2020 1925 3919.410 41.77955 -0.2679491  0.3096329779 -0.01965191

# %% [markdown]
# ## Multilevel model

# %%
# how many countries
length(unique(df$ctry))
# Out:
# [1] 19

# %% [markdown]
# I centered the variables to facilitate estimation.

# %%
ggplot(df, aes(y=le_log, x=gdp_log)) + geom_point(alpha=0.3) + theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ## Descriptives plots by country

# %% [markdown]
# ### LE and GDP (logs)
#
# Not always linear.

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
p = ggplot(data = df, aes(x = gdp_log, y = le_log)) + geom_point(alpha=0.3) + geom_smooth() + theme_minimal()
p + facet_wrap(~ctry)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ### LE and time
#
# Far from linear!

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
p = ggplot(data = df, aes(x = year_log, y = le_log)) + geom_point(alpha=0.3) + geom_smooth() + theme_minimal()
p + facet_wrap(~ctry)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# # Models

# %% [markdown]
# ### Only country random effects
#
# This is just to have a more basic model to compare with.

# %%
m1 = brm(formula = le_log ~ year_log + gdp_log + (1|ctry) , 
    data = df)
# Out:
# Compiling the C++ model
# Start sampling

# %%
summary(m1)
# Out:
#  Family: gaussian
#   Links: mu = identity; sigma = identity
# Formula: le_log ~ year_log + gdp_log + (1 | ctry)
#    Data: df (Number of observations: 343)
# Samples: 4 chains, each with iter = 2000; warmup = 1000; thin = 1;
#          total post-warmup samples = 4000
#     ICs: LOO = NA; WAIC = NA; R2 = NA
#
# Group-Level Effects:
# ~ctry (Number of levels: 19)
#               Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sd(Intercept)     0.11      0.02     0.07     0.16        686 1.01
#
# Population-Level Effects:
#           Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# Intercept    -0.00      0.03    -0.05     0.05        584 1.01
# year_log     17.25      0.78    15.72    18.80       1279 1.00
# gdp_log       0.06      0.02     0.02     0.11       1305 1.00
#
# Family Specific Parameters:
#       Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sigma     0.10      0.00     0.09     0.10       3378 1.00
#
# Samples were drawn using sampling(NUTS). For each parameter, Eff.Sample
# is a crude measure of effective sample size, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %% [markdown]
# ### Country and Time-varying coefficients (similar to Oeppen)

# %% [markdown]
# Both year and gdp effects vary by country.

# %%
m2 = brm(formula = le_log ~ year_log + gdp_log + (year_log + gdp_log | ctry), 
    data = df, control=list(adapt_delta=0.90))

# %%
summary(m2)
# Out:
# Warning message:
# “There were 1 divergent transitions after warmup. Increasing adapt_delta above 0.9 may help.
# See http://mc-stan.org/misc/warnings.html#divergent-transitions-after-warmup”
#  Family: gaussian
#   Links: mu = identity; sigma = identity
# Formula: le_log ~ year_log + gdp_log + (year_log + gdp_log | ctry)
#    Data: df (Number of observations: 343)
# Samples: 4 chains, each with iter = 2000; warmup = 1000; thin = 1;
#          total post-warmup samples = 4000
#     ICs: LOO = NA; WAIC = NA; R2 = NA
#
# Group-Level Effects:
# ~ctry (Number of levels: 19)
#                         Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sd(Intercept)               0.12      0.03     0.08     0.18       1345 1.00
# sd(year_log)                4.71      1.25     2.69     7.49       1727 1.00
# sd(gdp_log)                 0.10      0.03     0.04     0.18       1191 1.00
# cor(Intercept,year_log)    -0.29      0.27    -0.74     0.27       2059 1.00
# cor(Intercept,gdp_log)     -0.51      0.28    -0.91     0.15       2183 1.00
# cor(year_log,gdp_log)      -0.34      0.32    -0.82     0.40       2135 1.00
#
# Population-Level Effects:
#           Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# Intercept    -0.01      0.03    -0.07     0.06        827 1.00
# year_log     17.02      1.49    14.08    20.03       2150 1.00
# gdp_log       0.09      0.04     0.01     0.15       1815 1.00
#
# Family Specific Parameters:
#       Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sigma     0.08      0.00     0.08     0.09       4000 1.00
#
# Samples were drawn using sampling(NUTS). For each parameter, Eff.Sample
# is a crude measure of effective sample size, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %% [markdown]
# ### Adding a random time term

# %%
m3 = brm(formula = le_log ~ gdp_log + (gdp_log|ctry) + (1|year), 
    data = df)
# Out:
# Compiling the C++ model
# Start sampling

# %%
summary(m3)
# Out:
#  Family: gaussian
#   Links: mu = identity; sigma = identity
# Formula: le_log ~ gdp_log + (gdp_log | ctry) + (1 | year)
#    Data: df (Number of observations: 343)
# Samples: 4 chains, each with iter = 2000; warmup = 1000; thin = 1;
#          total post-warmup samples = 4000
#     ICs: LOO = NA; WAIC = NA; R2 = NA
#
# Group-Level Effects:
# ~ctry (Number of levels: 19)
#                        Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sd(Intercept)              0.13      0.02     0.09     0.19       1341 1.00
# sd(gdp_log)                0.11      0.02     0.07     0.17       1507 1.00
# cor(Intercept,gdp_log)    -0.81      0.14    -0.97    -0.45       1163 1.00
#
# ~year (Number of levels: 23)
#               Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sd(Intercept)     0.36      0.06     0.26     0.50        772 1.00
#
# Population-Level Effects:
#           Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# Intercept    -0.09      0.08    -0.25     0.07        588 1.00
# gdp_log       0.03      0.03    -0.04     0.10       1102 1.00
#
# Family Specific Parameters:
#       Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sigma     0.07      0.00     0.06     0.07       4000 1.00
#
# Samples were drawn using sampling(NUTS). For each parameter, Eff.Sample
# is a crude measure of effective sample size, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %% [markdown]
# ### Comparing models

# %%
l1 = LOO(m1)
l2 = LOO(m2)
l3 = LOO(m3)

# %%
compare(l1, l2, l3)
# Out:
#    looic             se_looic         elpd_loo         se_elpd_loo
# l3 -800.515974454276 42.132811594469  400.257987227138 21.0664057972345
# l2 -686.765554776001 30.3948996266189 343.382777388    15.1974498133094
# l1 -606.586489123809 28.5420677999026 303.293244561905 14.2710338999513
#    p_loo            se_p_loo
# l3 59.3544539591089 8.07555854816383
# l2 42.0787632820566 4.96913755618302
# l1 20.2182887034801 1.82110621600025

# %% [markdown]
# Model 3 is better.

# %% [markdown]
# ### Plotting predictions Model 2

# %% [markdown]
# Predicted values using all random effectsm from model 2! GOF is not good (only linear trend). The random effects correct overfitting by shrinking extreme values towards the mean.

# %%
pred = cbind(df[, .(ctry, year, year_log, gdp_log, le_log)], predict(m2))
setnames(pred, c('Estimate', '2.5%ile', '97.5%ile'), c('m', 'lo', 'hi'))

# %%
countries = unique(pred$ctry)

# %%
for (i in 1:length(countries)) {
    assign(paste0('plot', i), 
           ggplot(pred[ctry==countries[i]], aes(x=year_log, y=le_log)) + 
           geom_line(aes(y=m), color='#2b8cbe', size = 0.4)  +
           geom_ribbon(aes(ymin = lo, ymax = hi), fill = '#a6bddb', alpha=0.2)  + 
           geom_point(size=1, color='#e34a33', alpha=0.4) +
           labs(title=paste0('Country ',countries[i])) + 
           ylim(-0.9, 0.7) + 
           xlim(-.04, .03) + theme_minimal()
       )

}

# %%
options(repr.plot.width = 7, repr.plot.height = 20)
eval(parse(text=paste0(paste0('plot', 1:length(countries), collapse='+'), '+plot_layout(ncol = 3)')))
# Out:
# plot without title

# %% [markdown]
# # Random effects (Model 2)

# %%
re = ranef(m2) # get random effects

# %%
re$ctry

# %%
re_year = re$ctry[, c(1,3,4), 1]
re_year = data.table(year= rownames(re_year), re_year)
setnames(re_year, names(re_year), c('country', 'm', 'lo', 'hi'))

# %%
setkey(re_year, m)

re_year[, country := as_factor(country)]

# %%
options(repr.plot.width = 5, repr.plot.height = 4)
ggplot(re_year, aes(x=country, y=m)) + 
geom_line(color='#2b8cbe', size = 0.4, group=1) + 
   geom_ribbon(aes(ymin = lo, ymax = hi), fill = '#a6bddb', alpha=0.2, group=1) + 
   labs(y='Year random effect by country') + 
   theme(axis.text.x = element_text(angle = 60, hjust = 1))
# Out:
# plot without title

# %%
re_gdp = re$ctry[, c(1,3,4), 2]
re_gdp  = data.table(country= rownames(re_gdp), re_gdp)
setnames(re_gdp, names(re_gdp), c('country', 'm', 'lo', 'hi'))

# %%
setkey(re_gdp, m)
re_gdp[, country := as_factor(country)]

# %%
options(repr.plot.width = 5, repr.plot.height = 4)
ggplot(re_gdp, aes(x=country, y=m)) + 
geom_line(color='#2b8cbe', size = 0.4, group=1) + 
   geom_ribbon(aes(ymin = lo, ymax = hi), fill = '#a6bddb', alpha=0.2, group=1) + 
   labs(y='GDP random effect by country') + 
   theme(axis.text.x = element_text(angle = 60, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# ## Time Polynomials
#
# When adding time squared term and they are allowed to vary by country.

# %%
df[, year_log2 := year_log^2]
df[, year_log3 := year_log^3]

# %%
m3 = brm(formula = le_log ~ year_log + year_log2 + gdp_log + 
         (year_log + year_log2 + gdp_log | ctry), 
    data = df, control=list(adapt_delta=0.90))
# Out:
# Compiling the C++ model
# Start sampling
# Warning message:
# “There were 7 divergent transitions after warmup. Increasing adapt_delta above 0.9 may help. See
# http://mc-stan.org/misc/warnings.html#divergent-transitions-after-warmup”Warning message:
# “Examine the pairs() plot to diagnose sampling problems
# ”

# %%
summary(m3)
# Out:
# Warning message:
# “There were 7 divergent transitions after warmup. Increasing adapt_delta above 0.9 may help.
# See http://mc-stan.org/misc/warnings.html#divergent-transitions-after-warmup”
#  Family: gaussian
#   Links: mu = identity; sigma = identity
# Formula: le_log ~ year_log + year_log2 + gdp_log + (year_log + year_log2 + gdp_log | ctry)
#    Data: df (Number of observations: 343)
# Samples: 4 chains, each with iter = 2000; warmup = 1000; thin = 1;
#          total post-warmup samples = 4000
#     ICs: LOO = NA; WAIC = NA; R2 = NA
#
# Group-Level Effects:
# ~ctry (Number of levels: 19)
#                          Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sd(Intercept)                0.13      0.02     0.09     0.18       1060 1.00
# sd(year_log)                 5.79      1.19     3.89     8.55       1146 1.00
# sd(year_log2)              233.81     53.24   141.69   347.91       1341 1.00
# sd(gdp_log)                  0.05      0.03     0.00     0.12        568 1.01
# cor(Intercept,year_log)     -0.43      0.19    -0.75    -0.03       1346 1.00
# cor(Intercept,year_log2)    -0.43      0.19    -0.75    -0.00       1512 1.00
# cor(year_log,year_log2)     -0.41      0.22    -0.77     0.06       1843 1.00
# cor(Intercept,gdp_log)      -0.23      0.39    -0.85     0.64       2481 1.00
# cor(year_log,gdp_log)       -0.20      0.38    -0.79     0.63       1775 1.00
# cor(year_log2,gdp_log)       0.11      0.39    -0.66     0.79       2243 1.00
#
# Population-Level Effects:
#           Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# Intercept     0.03      0.03    -0.03     0.09        729 1.01
# year_log     18.18      1.63    15.08    21.41       1050 1.01
# year_log2  -253.30     63.84  -380.18  -132.32       1202 1.00
# gdp_log       0.08      0.03     0.03     0.13       1887 1.00
#
# Family Specific Parameters:
#       Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sigma     0.07      0.00     0.06     0.07       4000 1.00
#
# Samples were drawn using sampling(NUTS). For each parameter, Eff.Sample
# is a crude measure of effective sample size, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %% [markdown]
# # INLA + Random Walk (same trend by country)
#
# Random gdp term by country! Much much better fit... I have to figure out how to run this using stan, because here I use INLA.

# %%
library(INLA)
library(brinla)

# %%
df[, ctry_gdp := ctry]

# %%
formula = le_log ~ gdp_log + f(year, model = 'rw2') +
    f(ctry, model = 'iid') + 
    f(ctry_gdp, gdp_log, model = 'iid')
    
m4 = inla(formula, 
          control.compute = list(dic = TRUE),
          family = 'gaussian', 
          data = df)

# %%
round(m4$summary.fixed, 3)
# Out:
#             mean   sd    0.025quant 0.5quant 0.975quant mode   kld
# (Intercept) -0.087 0.030 -0.146     -0.087   -0.029     -0.086 0
# gdp_log      0.024 0.033 -0.042      0.024    0.090      0.023 0

# %%
bri.hyperpar.summary(m4)
# Out:
#                                  mean        sd           q0.025
# SD for the Gaussian observations 0.066602659 0.0027770034 0.061418226
# SD for year                      0.003416823 0.0006462102 0.002347259
# SD for ctry                      0.125275094 0.0218118849 0.089086024
# SD for ctry_gdp                  0.105691597 0.0222691295 0.069890148
#                                  q0.5        q0.975      mode
# SD for the Gaussian observations 0.066495596 0.072316919 0.066200947
# SD for year                      0.003345358 0.004876336 0.003203015
# SD for ctry                      0.122862025 0.174469333 0.117952307
# SD for ctry_gdp                  0.102851036 0.156957096 0.097241815

# %% [markdown]
# ### Plot predictions

# %%
fit = m4$summary.fitted.values
pred = data.table(df, m= fit$'0.5quant', lo = fit$'0.025quant', hi = fit$'0.975quant')

# %%
countries = unique(pred$ctry)

# %%
for (i in 1:length(countries)) {
    assign(paste0('plot', i), 
           ggplot(pred[ctry==countries[i]], aes(x=year, y=le_log)) + 
           geom_line(aes(y=m), color='#2b8cbe', size = 0.4)  +
           geom_ribbon(aes(ymin = lo, ymax = hi), fill = '#a6bddb', alpha=0.2)  + 
           geom_point(size=1, color='#e34a33', alpha=0.4) +
           labs(title=paste0('Country ',countries[i])) + 
           ylim(-0.9, 0.7) + 
           xlim(1889, 2011) +
           theme_minimal()
       )

}

# %%
options(repr.plot.width = 7, repr.plot.height = 20)
eval(parse(text=paste0(paste0('plot', 1:length(countries), collapse='+'), '+plot_layout(ncol = 3)')))
# Out:
# plot without title

# %% [markdown]
# # Variable transformation

# %% [markdown]
# - Suppose for each country we have the maximum value of life expectancy in the last year of observation, max(E).
# - Then, for each year t compute Y(t)= E(t)/Max(E). We now have two options, a Gompertz or a Weibull:
#
#
# ### Gompertz
#
# $$Z(t)=ln(-ln Y(t))=A + Bt$$
# and we make A a function of GDP so the model is as we have it now but with Z(t) as dependent variable. That is the baseline model will look as follows:
#
# $$Z(t) = Ao+A1lnGDP+B*t$$
#
# and Ao, A1 and B will be specified as a random effects
#
#
# In the Gompertz we can use centered values of t but not in the Weibull unless we transform t

# %%
df[, y := le/max(le+1.05), by = ctry] # by country, really!!!

# %%
max_le = df[, .(max_le = max(le+1.05)), by = ctry] # by country, really!!!

# %%
df[, gy := log(-log(y))]
summary(df$gy)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -4.361151 -2.495325 -1.378437 -1.609385 -0.476357 -0.003456

# %% [markdown]
# Does this make sense? Negative values?

# %%
options(repr.plot.width = 4, repr.plot.height = 3)
ggplot(df, aes(gy)) + geom_histogram(bins=30)
# Out:
# plot without title

# %%
m4 = brm(formula = gy ~ year_c + gdp_log + 
         (year_c + gdp_log | ctry), 
    data = df)
# Out:
# Compiling the C++ model
# Start sampling

# %%
summary(m4)
# Out:
#  Family: gaussian
#   Links: mu = identity; sigma = identity
# Formula: gy ~ year_c + gdp_log + (year_c + gdp_log | ctry)
#    Data: df (Number of observations: 343)
# Samples: 4 chains, each with iter = 2000; warmup = 1000; thin = 1;
#          total post-warmup samples = 4000
#     ICs: LOO = NA; WAIC = NA; R2 = NA
#
# Group-Level Effects:
# ~ctry (Number of levels: 19)
#                        Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sd(Intercept)              0.33      0.09     0.19     0.53       1533 1.00
# sd(year_c)                 0.02      0.00     0.01     0.03       1078 1.00
# sd(gdp_log)                0.90      0.22     0.54     1.42       1032 1.00
# cor(Intercept,year_c)     -0.21      0.27    -0.69     0.34       1057 1.00
# cor(Intercept,gdp_log)     0.08      0.27    -0.45     0.57       1203 1.00
# cor(year_c,gdp_log)       -0.84      0.10    -0.96    -0.57       1685 1.00
#
# Population-Level Effects:
#           Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# Intercept    -1.39      0.09    -1.58    -1.20       1466 1.00
# year_c       -0.04      0.00    -0.05    -0.04       1497 1.00
# gdp_log       0.01      0.25    -0.48     0.52       1288 1.00
#
# Family Specific Parameters:
#       Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sigma     0.37      0.02     0.34     0.40       4000 1.00
#
# Samples were drawn using sampling(NUTS). For each parameter, Eff.Sample
# is a crude measure of effective sample size, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %% [markdown]
# ### Plot predictions

# %%
pred = cbind(df[, .(ctry, le, year, year_c, gdp_log, gy)], predict(m4))
setnames(pred, c('Estimate', '2.5%ile', '97.5%ile'), c('m', 'lo', 'hi'))
pred = merge(pred, max_le, by='ctry')

get_orig_values_gompertz = function(x, max_value) { 
    return ( (exp(-exp(x)) * max_value ))
}

# %%
pred[,  `:=` (
    m = get_orig_values_gompertz(m, max_le), 
    lo = get_orig_values_gompertz(lo, max_le),
    hi = get_orig_values_gompertz(hi, max_le)
    )]

# %%
countries = unique(pred$ctry)

# %%
for (i in 1:length(countries)) {
    assign(paste0('plot', i), 
           ggplot(pred[ctry==countries[i]], aes(x=year, y=le)) + 
           geom_line(aes(y=m), color='#2b8cbe', size = 0.4)  +
           geom_ribbon(aes(ymin = lo, ymax = hi), fill = '#a6bddb', alpha=0.2)  + 
           geom_point(size=1, color='#e34a33', alpha=0.4) +
           labs(title=paste0('Country ',countries[i])) + 
           ylim(min(df$le)-30.0, max(df$le)+20.0) + 
           xlim(min(df$year), max(df$year)) + theme_minimal()
       )

}

# %%
options(repr.plot.width = 7, repr.plot.height = 20)
eval(parse(text=paste0(paste0('plot', 1:length(countries), collapse='+'), '+plot_layout(ncol = 3)')))
# Out:
# plot without title

# %% [markdown]
# ## Weibull

# %% [markdown]
# $$ln(-ln(1-Y(t))=C+D*lnt$$
#
# and we make C a function of GDP and the model is as we have it now but with W(t) as dependent variable.
#
# So what I did is:
#
#
# $$W(t) = \alpha+\beta_g lnGDP+\beta_t*lnt$$
#
# and $\alpha$, $\beta_g$ and $\beta_t$ are be specified as a random effects

# %%
df[, wy := log(-log(1-y))]
df[, year_ln := log(year)]

# %%
summary(df$wy)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -0.7750 -0.2603  0.4067  0.3615  0.9307  1.4742

# %%
options(repr.plot.width = 4, repr.plot.height = 3)
ggplot(df, aes(wy)) + geom_histogram(bins=30)
# Out:
# plot without title

# %%
m5 = brm(formula = wy ~ year_log + gdp_log + 
         (year_log + gdp_log | ctry), 
    data = df)
# Out:
# Compiling the C++ model
# Start sampling

# %%
summary(m5)
# Out:
#  Family: gaussian
#   Links: mu = identity; sigma = identity
# Formula: wy ~ year_log + gdp_log + (year_log + gdp_log | ctry)
#    Data: df (Number of observations: 343)
# Samples: 4 chains, each with iter = 2000; warmup = 1000; thin = 1;
#          total post-warmup samples = 4000
#     ICs: LOO = NA; WAIC = NA; R2 = NA
#
# Group-Level Effects:
# ~ctry (Number of levels: 19)
#                         Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sd(Intercept)               0.18      0.04     0.11     0.27       1605 1.00
# sd(year_log)               11.08      2.65     6.60    16.99       1521 1.00
# sd(gdp_log)                 0.29      0.07     0.17     0.44       1331 1.00
# cor(Intercept,year_log)    -0.35      0.23    -0.73     0.14       1743 1.00
# cor(Intercept,gdp_log)      0.02      0.27    -0.50     0.53       1835 1.00
# cor(year_log,gdp_log)      -0.66      0.18    -0.90    -0.23       1696 1.00
#
# Population-Level Effects:
#           Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# Intercept     0.30      0.05     0.21     0.39       1253 1.00
# year_log     43.96      3.01    37.83    50.08       1769 1.00
# gdp_log       0.07      0.08    -0.08     0.24       1812 1.00
#
# Family Specific Parameters:
#       Estimate Est.Error l-95% CI u-95% CI Eff.Sample Rhat
# sigma     0.13      0.01     0.12     0.14       4000 1.00
#
# Samples were drawn using sampling(NUTS). For each parameter, Eff.Sample
# is a crude measure of effective sample size, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %% [markdown]
# The effect of gdp is uncertain.

# %%
pred = cbind(df[, .(ctry, le, year, year_log, gdp_log, wy)], predict(m5))
setnames(pred, c('Estimate', '2.5%ile', '97.5%ile'), c('m', 'lo', 'hi'))
pred = merge(pred, max_le, by='ctry')

# %%
get_orig_values_weibull = function(x, max_value) { 
    return ( (1 - exp(-exp(x))) * max_value )
}

# %%
pred[,  `:=` (
    m = get_orig_values_weibull(m, max_le), 
    lo = get_orig_values_weibull(lo, max_le),
    hi = get_orig_values_weibull(hi, max_le)
    )]

# %%
for (i in 1:length(countries)) {
    assign(paste0('plot', i), 
           ggplot(pred[ctry==countries[i]], aes(x=year, y=le)) + 
           geom_line(aes(y=m), color='#2b8cbe', size = 0.4)  +
           geom_ribbon(aes(ymin = lo, ymax = hi), fill = '#a6bddb', alpha=0.2)  + 
           geom_point(size=1, color='#e34a33', alpha=0.4) +
           labs(title=paste0('Country ',countries[i])) + 
           ylim(min(df$le)-25.0, max(df$le)+25.0) + 
           xlim(min(df$year), max(df$year)) + theme_minimal()
       )

}

# %%
options(repr.plot.width = 7, repr.plot.height = 20)
eval(parse(text=paste0(paste0('plot', 1:length(countries), collapse='+'), '+plot_layout(ncol = 3)')))
# Out:
# plot without title
